# %%
import pandas as pd
import json

# %%
with open('data/business.json') as f:
    businesses = pd.DataFrame([json.loads(line) for line in f])

# %%
# !head -n 100 data/review.json > data/review100.json

# %%
with open('data/review100.json') as f:
    reviews = pd.DataFrame([json.loads(line) for line in f])

# %%
qc = businesses[businesses.state == 'QC']

# %%
qc.to_csv('data/qc_review.csv', encoding='utf8')

# %%
with open('data/qc_business_ids.txt', 'w') as f:
    for l in qc.business_id.values:
        f.write(l + "\n")

# %%
qc.longitude.min(), qc.longitude.max()
# Out:
# (-73.994516000000004, -73.450193499999997)

# %%
qc.latitude.min(), qc.latitude.max()
# Out:
# (45.402067299999999, 45.730644268608401)

# %%
qc = qc.set_index('name');

# %%
qc.attributes
# Out:
# name
# Atomic Cafe                        {u'Take-out': True, u'Caters': False, u'Noise ...
# Restaurant Les Princesses          {u'Alcohol': u'beer_and_wine', u'Noise Level':...
# La Cage Aux Sports                 {u'Alcohol': u'full_bar', u'Good For Dancing':...
# Boulangerie Première Moisson                                                      {}
# Jardin Tiki                        {u'Take-out': True, u'Accepts Credit Cards': T...
# Restaurant St-Hubert Rotisserie                                                   {}
# Biodôme de Montréal                {u'Good For Kids': True, u'Price Range': 1, u'...
# Boston Pizza Anjou                 {u'Take-out': True, u'Accepts Credit Cards': T...
# Barbies Bar & Grill                {u'Price Range': 2, u'Good For': {u'dessert': ...
# Al's Sousmarins                    {u'Ambience': {u'romantic': False, u'intimate'...
# Loblaws                            {u'Accepts Credit Cards': True, u'Price Range'...
# ...

# %%
qc.plot(x='longitude', y='latitude', kind='scatter', s=qc.review_count, figsize=(5,5), alpha=qc.stars)

# %%
reviews
# Out:
#                business_id        date               review_id  stars  \
# 0   vcNAWiLM4dR7D2nwwJ7nCA  2007-05-17  15SdjuK7DmYqUAj6rjGowg      5
# 1   vcNAWiLM4dR7D2nwwJ7nCA  2010-03-22  RF6UnRTtG7tWMcrO2GEoAg      2
# 2   vcNAWiLM4dR7D2nwwJ7nCA  2012-02-14  -TsVN230RCkLYKBeLsuz7A      4
# 3   vcNAWiLM4dR7D2nwwJ7nCA  2012-03-02  dNocEAyUucjT371NNND41Q      4
# 4   vcNAWiLM4dR7D2nwwJ7nCA  2012-05-15  ebcN2aqmNUuYNoyvQErgnA      4
# 5   vcNAWiLM4dR7D2nwwJ7nCA  2013-04-19  _ePLBPrkrf4bhyiKWEn4Qg      1
# 6   vcNAWiLM4dR7D2nwwJ7nCA  2014-01-02  kMu0knsSUFW2DZXqKkGWlg      5
# 7   vcNAWiLM4dR7D2nwwJ7nCA  2014-01-08  onDPFgNZpMk-bT1zlForRA      5
# 8   vcNAWiLM4dR7D2nwwJ7nCA  2014-08-01  bOJD0Kc3wGioat3oSFqgPQ      1
# 9   vcNAWiLM4dR7D2nwwJ7nCA  2014-12-12  QzjRXUNSGk3PySEcg5y92g      5
# 10  UsFtqoBl7naz8AVUBZMjQQ  2013-11-08  Di3exaUCFNw1V4kSNW5pgA      5
# 11  UsFtqoBl7naz8AVUBZMjQQ  2014-03-29  0Lua2-PbqEQMjD9r89-asw      3
# ...

# %%
qc_reviews = []
with open('data/review.json') as f:
    for line in f:
        r = json.loads(line)
        if r['business_id'] in qc.business_id.values:
            qc_reviews.append(r)

# %%
qc.business_id.values

# %%
'lW9Up8oVTWUEut_R6nZG-g' in qc.business_id.values
# Out:
# True
