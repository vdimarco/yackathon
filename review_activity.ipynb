# %%
import pandas as pd

# %%
df = pd.read_csv('data/review_activity.csv')

# %%
df.date = pd.to_datetime(df.date)

# %%
df.set_index('date', inplace=True)

# %%
df.business_id.resample('M', how='count').plot(figsize=(15,9))

# %%
df[df.codes == 'H2X '].business_id.resample('M', how='count').plot(figsize=(15,9))

# %%
df[df.codes == 'H2W '].business_id.resample('M', how='count').plot(figsize=(15,9))

# %%
df[df.codes == 'H2T '].business_id.resample('M', how='count').plot(figsize=(15,9))

# %%
df[df.codes == 'H2T '].business_id.resample('M', how='count').plot(figsize=(15,9))

# %%
activity = pd.read_csv('features/year_reviews.csv')

# %%
activity.sort('business_activity_2014', ascending=False)
# Out:
#      Unnamed: 0  index  business_activity_2014  user_activity_2014  \
# 571         571   1949                     NaN                 NaN
# 581         581   H9A                      NaN                 NaN
# 588         588  25589                     NaN                 NaN
# 546         546  28253                     NaN                 NaN
# 439         439  85246                     NaN                 NaN
# 585         585  45700                     NaN                 NaN
# 548         548  89085                     NaN                 NaN
# 462         462  89195                     NaN                 NaN
# 580         580  75063                     NaN                 NaN
# 13           13    NaN                     NaN                 NaN
# 578         578   H7R                      NaN                 NaN
# 577         577  85272                     NaN                 NaN
# 499         499  85076                     NaN                 NaN
# ...

# %%
vegas = '89109'
df[df.codes == vegas].business_id.resample('M', how='count').plot(figsize=(15,9))
